# %% [markdown]
# <a href="https://colab.research.google.com/github/soumabkargit/intro-to-machine-learning/blob/master/Blending_Two_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import cv2

# Authentification Google
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download du fichier
id = '1T0LqOHztZ1wpVl8O4u-qxcQ_kiwDehbb'
downloaded = drive.CreateFile({'id': '1T0LqOHztZ1wpVl8O4u-qxcQ_kiwDehbb'})
downloaded.GetContentFile('test_2.jpg')
id = '158BosNY5jb_dJXNCDvPYp5CiihoVTP0K'
downloaded = drive.CreateFile({'id': '158BosNY5jb_dJXNCDvPYp5CiihoVTP0K'})
downloaded.GetContentFile('test_3.jpg')

#Read image 1
img1 = cv2.imread('test_2.jpg')
#Read image 2
img2 = cv2.imread('test_3.jpg')
#Define alpha and beta
alpha = 0.30
beta = 0.70
#Blend images
final_image = cv2.addWeighted(img1, alpha, img2, beta, 0.0)
#Show image
io.imshow(final_image)
